# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Solved state coordinates
points = {
    1: (-1, 1, -1), # 1
    2: (0, 1, -1), # 2
    3: (1, 1, -1), # 3
    4: (1, 0, -1) , # 4
    5: (0, 0, -1), # 5
    6: (0, 0, 0), # 6
    7: (0, 0, 1), # 7
    8: (0, -1, 1), # 8
    9: (0, -1, 0), # 9
    10: (0, -1, -1), # 10   
    11: (1, -1, -1), # 11
    12: (1, -1, 0), # 12
    13: (1, 0, 0), # 13
    14: (1, 1, 0), # 14
    15: (0, 1, 0), # 15
    16: (-1, 1, 0), # 16
    17: (-1, 0, 0), # 17
    18: (-1, 0, -1), # 18
    19: (-1, -1, -1), # 19
    20: (-1, -1, 0), # 20
    21: (-1, -1, 1), # 21
    22: (-1, 0, 1), # 22
    23: (-1, 1, 1), # 23
    24: (0, 1, 1), # 24
    25: (1, 1, 1), # 25
    26: (1, 0, 1), # 26
    27: (1, -1, 1), # 27
}
beads = {
    1: (-5, 2, -6),
    2: (-5, 2, -5),
    3: (-5, 2, -4),
    4: (-4, 2, -4),
    5: (-3, 2, -4),
    6: (-3, 2, -3),
    7: (-3, 2, -2),
    8: (-2, 2, -2),
    9: (-1, 2, -2),
    10: (-1, 2, -1),
    11: (0, 2, -1),
    12: (0, 2, 0),
    13: (0, 1, 0),
    14: (0, 0, 0),
    15: (1, 0, 0),
    16: (2, 0, 0),
    17: (2, 0, 1),
    18: (3, 0, 1),
    19: (3, 0, 2),
    20: (3, 0, 3),
    21: (4, 0, 3),
    22: (4, 0, 4),
    23: (4, 0, 5),
    24: (5, 0, 5),
    25: (5, 0, 6),
    26: (6, 0, 6),
    27: (7, 0, 6),
}
# points = list(beads.values())

# Extract x, y, z coordinates
x, y, z = zip(*points.values())

# Create a 3D scatter plot
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the points
ax.scatter(x, y, z, c='blue', s=100)

# Annotate each point with its index
for i, (px, py, pz) in enumerate(points.values(), 1):
    ax.text(px, py, pz, f'{i}', color='red')

# Set plot limits
ax.set_xlim([-4, 4])
ax.set_ylim([-4, 4])
ax.set_zlim([-4, 4])

# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('Solved Snake Rubik Puzzle (3x3x3 Cube)')

# Show the grid and plot
ax.grid(True)
plt.show()
